# %%
# !python --version
# !pip show torch
# Out:
# Python 3.12.3
# Name: torch
# Version: 2.2.2
# Summary: Tensors and Dynamic neural networks in Python with strong GPU acceleration
# Home-page: https://pytorch.org/
# Author: PyTorch Team
# Author-email: packages@pytorch.org
# License: BSD-3
# Location: /Users/user/adelaide-zephyrine-charlotte-assistant/.venv/lib/python3.12/site-packages
# Requires: filelock, fsspec, jinja2, networkx, sympy, typing-extensions
# Required-by: accelerate, peft, trl

# %%
import os

# Set the TRANSFORMERS_CACHE environment variable
os.environ["TRANSFORMERS_CACHE"] = "./huggingface_cache"
#HF_HOME
os.environ["HF_HOME"] = "./huggingface_cache"

#Unlock Apple Silicon MPS VRAM to infinity
#os.environ["PYTORCH_MPS_HIGH_WATERMARK_RATIO"] = "0.0"
os.environ["PYTORCH_ENABLE_MPS_FALLBACK"] = "1"

# %%
# !pip install --upgrade pip
# !pip install -U wheel
# !pip show transformers accelerate
# !pip install -U transformers accelerate peft trl pandas
# !pip install datasets bitsandbytes einops
# !pip install scikit-learn
# !pip install accelerate
# !pip install -i https://pypi.org/simple/ bitsandbytes
# !pip install SentencePiece
# !pip install packaging
#compile flash_attn
import packaging

#!pip install flash_attn #Nvidia focus exclusive

# !pip uninstall wandb -y

# !pip install tqdm ipywidgets
# Out:
# ...
# Name: transformers
# Version: 4.40.1
# Summary: State-of-the-art Machine Learning for JAX, PyTorch and TensorFlow
# Home-page: https://github.com/huggingface/transformers
# Author: The Hugging Face team (past and future) with the help of all our contributors (https://github.com/huggingface/transformers/graphs/contributors)
# Author-email: transformers@huggingface.co
# License: Apache 2.0 License
# Location: /Users/user/adelaide-zephyrine-charlotte-assistant/.venv/lib/python3.12/site-packages
# Requires: filelock, huggingface-hub, numpy, packaging, pyyaml, regex, requests, safetensors, tokenizers, tqdm
# Required-by: peft, trl
# ---
# Name: accelerate
# Version: 0.29.3
# Summary: Accelerate
# Home-page: https://github.com/huggingface/accelerate
# Author: The HuggingFace team
# Author-email: zach.mueller@huggingface.co
# License: Apache
# Location: /Users/user/adelaide-zephyrine-charlotte-assistant/.venv/lib/python3.12/site-packages
# ...

# %%
# !pwd
# Out:
# /Users/user/adelaide-zephyrine-charlotte-assistant/usr/engine_component/generalReintegrationPyWorkstationEnv/LLMReintegrationExperiment

# %%
# !python ./SuperAdapters/finetune.py --model_type mixtral --data "data/train/" --model_path "Open-Orca/Mistral-7B-OpenOrca" --adapter "lora" --output_dir "output/mixtral"
# Out:
# /opt/homebrew/Cellar/python@3.12/3.12.3/Frameworks/Python.framework/Versions/3.12/Resources/Python.app/Contents/MacOS/Python: can't open file '/Users/user/adelaide-zephyrine-charlotte-assistant/usr/engine_component/generalReintegrationPyWorkstationEnv/LLMReintegrationExperiment/finetune.py': [Errno 2] No such file or directory
